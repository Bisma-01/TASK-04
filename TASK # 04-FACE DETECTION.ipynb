# %% [markdown]
# # TASK # 04

# %%
pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 4️⃣4️⃣4️⃣4️⃣4️⃣4️⃣FACE DETECTION4️⃣4️⃣4️⃣4️⃣4️⃣4️⃣

# %% [markdown]
# # IMPORT LIBRARIES:

# %%
import cv2
import os
import pandas as pd
import numpy as np
from IPython.display import Image, display

# %%
import cv2
import os

# Load the pre-trained face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

video_path = 'C:/Users/meera/Downloads/MACHINE LEARNING/IMAGE PROCC-DL/database/video.mp4'

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if the video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

output_folder = 'detected_faces'
os.makedirs(output_folder, exist_ok=True)

image_count = 1

while True:

    ret, frame = cap.read()

    if not ret:
        break  

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        detected_face = frame[y:y+h, x:x+w]
        cv2.imwrite(os.path.join(output_folder, f'detected_face_{image_count}.jpg'), detected_face)
        image_count += 1

    cv2.imshow('Detected Faces', frame)

    if cv2.waitKey(50) & 0xFF == ord('q'):
        break

# Release the video capture object and close all windows
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # OUTPUT RESULT

# %%
from IPython.display import Image, display

filename = r'C:\Users\meera\OneDrive\Desktop\DETECTED FACE.png'

display(Image(filename=filename))
